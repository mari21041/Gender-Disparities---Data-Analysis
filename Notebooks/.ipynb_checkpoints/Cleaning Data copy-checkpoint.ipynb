# %%
import numpy as np
import pandas as pd
import re
from pathlib import Path

# %%
df= pd.read_csv('../data/raw/Human Development Index - Full.csv')
df.head()
# Out:
#   ISO3               Country Human Development Groups UNDP Developing Regions  \
# 0  AFG           Afghanistan                      Low                      SA
# 1  AGO                Angola                   Medium                     SSA
# 2  ALB               Albania                     High                     ECA
# 3  AND               Andorra                Very High                     NaN
# 4  ARE  United Arab Emirates                Very High                      AS
#
#    HDI Rank (2021)  Human Development Index (1990)  \
# 0            180.0                           0.273
# 1            148.0                             NaN
# 2             67.0                           0.647
# 3             40.0                             NaN
# 4             26.0                           0.728
#
#    Human Development Index (1991)  Human Development Index (1992)  \
# 0                           0.279                           0.287
# 1                             NaN                             NaN
# 2                           0.629                           0.614
# 3                             NaN                             NaN
# 4                           0.739                           0.742
#
#    Human Development Index (1993)  Human Development Index (1994)  ...  \
# 0                           0.297                           0.292  ...
# 1                             NaN                             NaN  ...
# 2                           0.617                           0.624  ...
# 3                             NaN                             NaN  ...
# 4                           0.748                           0.755  ...
#
#    Material footprint per capita (tonnes) (2012)  \
# 0                                           1.86
# 1                                           4.09
# 2                                          12.44
# 3                                            NaN
# 4                                          49.56
#
#    Material footprint per capita (tonnes) (2013)  \
# 0                                           1.88
# 1                                           4.53
# 2                                          11.49
# 3                                            NaN
# 4                                          49.68
#
#    Material footprint per capita (tonnes) (2014)  \
# 0                                           1.66
# 1                                           3.97
# 2                                          13.14
# 3                                            NaN
# 4                                          55.49
#
#    Material footprint per capita (tonnes) (2015)  \
# 0                                           1.62
# 1                                           3.59
# 2                                          12.61
# 3                                            NaN
# 4                                          59.76
#
#    Material footprint per capita (tonnes) (2016)  \
# 0                                           1.66
# 1                                           2.79
# 2                                          14.39
# 3                                            NaN
# 4                                          64.95
#
#    Material footprint per capita (tonnes) (2017)  \
# 0                                           1.41
# 1                                           2.64
# 2                                          14.46
# 3                                            NaN
# 4                                          75.61
#
#    Material footprint per capita (tonnes) (2018)  \
# 0                                           1.32
# 1                                           2.28
# 2                                          12.85
# 3                                            NaN
# 4                                          65.97
#
#    Material footprint per capita (tonnes) (2019)  \
# 0                                           1.38
# 1                                           2.18
# 2                                          12.96
# 3                                            NaN
# 4                                          68.95
#
#    Material footprint per capita (tonnes) (2020)  \
# 0                                           1.38
# 1                                           2.18
# 2                                          12.96
# 3                                            NaN
# 4                                          68.95
#
#    Material footprint per capita (tonnes) (2021)
# 0                                           1.38
# 1                                           2.18
# 2                                          12.96
# 3                                            NaN
# 4                                          68.95
#
# [5 rows x 880 columns]

# %%
df.shape
# Out:
# (195, 880)

# %%
df.columns
# Out:
# Index(['ISO3', 'Country', 'Human Development Groups',
#        'UNDP Developing Regions', 'HDI Rank (2021)',
#        'Human Development Index (1990)', 'Human Development Index (1991)',
#        'Human Development Index (1992)', 'Human Development Index (1993)',
#        'Human Development Index (1994)',
#        ...
#        'Material footprint per capita (tonnes) (2012)',
#        'Material footprint per capita (tonnes) (2013)',
#        'Material footprint per capita (tonnes) (2014)',
#        'Material footprint per capita (tonnes) (2015)',
#        'Material footprint per capita (tonnes) (2016)',
#        'Material footprint per capita (tonnes) (2017)',
#        'Material footprint per capita (tonnes) (2018)',
#        'Material footprint per capita (tonnes) (2019)',
#        'Material footprint per capita (tonnes) (2020)',
#        'Material footprint per capita (tonnes) (2021)'],
#       dtype='object', length=880)

# %%
#DROPPING COLUMNS WITH YEARS FROM 1990 TO 2010 TO KEEP ONLY THE LAST 10 YEARS' INFORMATION
years_to_drop = tuple(f"({year})" for year in range(1990, 2011))
df = df.drop(columns=[col for col in df.columns if col.endswith(years_to_drop)])

# %%
df.shape
# Out:
# (195, 349)

# %%
# DROPPING IRRELEVANT COLUMNS
base_variables = [
    "Material footprint per capita (tonnes)",
    "Carbon dioxide emissions per capita (production) (tonnes)",
    "Planetary pressures-adjusted Human Development Index",
    "GII Rank",
    "GDI Group",
    "Inequality-adjusted Human Development Index "
]
years = range(1990, 2022)
columns_to_drop = [f"{var} ({year})" for var in base_variables for year in years]

df = df.drop(columns=[col for col in df.columns if col in columns_to_drop])

# %%
df.shape
# Out:
# (195, 314)

# %%
df.drop('ISO3', axis=1, inplace=True)

# %%
df.drop('UNDP Developing Regions', axis=1, inplace=True)

# %%
df.drop('Human Development Groups', axis=1, inplace=True)

# %%
df.shape
# Out:
# (195, 311)

# %%
# MELTING THE DATA SET

df_melted = df.melt(id_vars=["Country"], var_name="Variable_Year", value_name="Value")


df_melted["Year"] = df_melted["Variable_Year"].str.extract(r"\((\d{4})\)")


df_melted = df_melted.dropna(subset=["Year"])


df_melted["Year"] = df_melted["Year"].astype(int)


df_melted["Variable"] = df_melted["Variable_Year"].str.extract(r"^(.*) \(\d{4}\)")


df_long = df_melted[["Country", "Year", "Variable", "Value"]].sort_values(by=["Country", "Variable", "Year"]).reset_index(drop=True)

# %%
#PIVOTING
df_wide = df_long.pivot(index=["Country", "Year"], columns="Variable", values="Value").reset_index()
df_wide.head(50)
# Out:
# Variable      Country  Year  \
# 0         Afghanistan  2011
# 1         Afghanistan  2012
# 2         Afghanistan  2013
# 3         Afghanistan  2014
# 4         Afghanistan  2015
# 5         Afghanistan  2016
# 6         Afghanistan  2017
# 7         Afghanistan  2018
# 8         Afghanistan  2019
# 9         Afghanistan  2020
# 10        Afghanistan  2021
# 11            Albania  2011
# 12            Albania  2012
# 13            Albania  2013
# 14            Albania  2014
# 15            Albania  2015
# 16            Albania  2016
# 17            Albania  2017
# 18            Albania  2018
# 19            Albania  2019
# 20            Albania  2020
# 21            Albania  2021
# 22            Algeria  2011
# 23            Algeria  2012
# 24            Algeria  2013
# 25            Algeria  2014
# 26            Algeria  2015
# 27            Algeria  2016
# 28            Algeria  2017
# 29            Algeria  2018
# 30            Algeria  2019
# 31            Algeria  2020
# 32            Algeria  2021
# 33            Andorra  2011
# 34            Andorra  2012
# 35            Andorra  2013
# 36            Andorra  2014
# 37            Andorra  2015
# 38            Andorra  2016
# 39            Andorra  2017
# 40            Andorra  2018
# 41            Andorra  2019
# 42            Andorra  2020
# 43            Andorra  2021
# 44             Angola  2011
# 45             Angola  2012
# 46             Angola  2013
# 47             Angola  2014
# 48             Angola  2015
# 49             Angola  2016
#
# Variable  Adolescent Birth Rate (births per 1,000 women ages 15-19)  \
# 0                                                   116.454
# 1                                                   111.286
# 2                                                   106.537
# 3                                                   101.454
# 4                                                    97.415
# 5                                                    94.018
# 6                                                    90.342
# 7                                                    88.431
# 8                                                    86.803
# 9                                                    84.296
# 10                                                   82.565
# 11                                                   20.692
# 12                                                   20.909
# 13                                                   20.865
# 14                                                   20.942
# 15                                                   20.276
# 16                                                   18.171
# 17                                                   16.585
# 18                                                   15.580
# 19                                                   15.013
# 20                                                   14.672
# 21                                                   14.517
# 22                                                   11.134
# 23                                                   11.950
# 24                                                   12.684
# 25                                                   12.771
# 26                                                   11.888
# 27                                                   12.731
# 28                                                   12.872
# 29                                                   12.654
# 30                                                   12.303
# 31                                                   12.057
# 32                                                   11.714
# 33                                                    9.574
# 34                                                    8.414
# 35                                                    6.989
# 36                                                    6.925
# 37                                                    7.402
# 38                                                    7.176
# 39                                                    6.404
# 40                                                    6.080
# 41                                                    5.985
# 42                                                    6.091
# 43                                                    5.887
# 44                                                  159.295
# 45                                                  156.557
# 46                                                  153.345
# 47                                                  151.093
# 48                                                  148.074
# 49                                                  146.135
#
# Variable  Coefficient of human inequality  Difference from HDI rank  \
# 0                               29.495694                       NaN
# 1                               29.208713                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
# 5                                     NaN                       NaN
# 6                                     NaN                       NaN
# 7                                     NaN                       NaN
# 8                                     NaN                       NaN
# 9                                     NaN                       NaN
# 10                                    NaN                       5.0
# 11                              12.624666                       NaN
# 12                              10.429779                       NaN
# 13                              10.298332                       NaN
# 14                              10.198068                       NaN
# 15                              10.133330                       NaN
# 16                              10.100487                       NaN
# 17                              10.233289                       NaN
# 18                              10.554499                       NaN
# 19                              10.589337                       NaN
# 20                              10.727042                       NaN
# 21                              10.767685                      28.0
# 22                                    NaN                       NaN
# 23                                    NaN                       NaN
# 24                              19.842188                       NaN
# 25                              19.776358                       NaN
# 26                              19.713805                       NaN
# 27                              19.643913                       NaN
# 28                              19.568293                       NaN
# 29                              19.480038                       NaN
# 30                              19.297498                       NaN
# 31                              19.194810                       NaN
# 32                              19.072875                      16.0
# 33                                    NaN                       NaN
# 34                                    NaN                       NaN
# 35                                    NaN                       NaN
# 36                                    NaN                       NaN
# 37                                    NaN                       NaN
# 38                                    NaN                       NaN
# 39                                    NaN                       NaN
# 40                                    NaN                       NaN
# 41                                    NaN                       NaN
# 42                                    NaN                       NaN
# 43                                    NaN                       NaN
# 44                                    NaN                       NaN
# 45                                    NaN                       NaN
# 46                                    NaN                       NaN
# 47                                    NaN                       NaN
# 48                              32.040235                       NaN
# 49                              31.708308                       NaN
#
# Variable  Difference from HDI value (%)  Expected Years of Schooling  \
# 0                              1.315789                     9.278810
# 1                              1.072961                     9.577323
# 2                              1.054852                     9.875836
# 3                              1.043841                    10.174350
# 4                              0.836820                    10.180150
# 5                              0.831601                    10.185950
# 6                              0.829876                    10.191750
# 7                              0.828157                    10.197550
# 8                              0.819672                    10.263844
# 9                              0.828157                    10.263844
# 10                             0.836820                    10.263844
# 11                             7.049608                    13.748450
# 12                             6.940874                    14.586650
# 13                             6.624204                    14.925640
# 14                             7.575758                    15.252420
# 15                             7.044025                    15.076300
# 16                             7.769424                    14.804600
# 17                             8.104738                    14.816130
# 18                             7.196030                    14.695620
# 19                             7.283951                    14.818920
# 20                             7.178841                    14.448000
# 21                             7.160804                    14.448000
# 22                             6.877579                    14.332280
# 23                             6.858711                    14.332280
# 24                             6.839945                    14.332280
# 25                             7.074830                    14.381383
# 26                             7.162162                    14.430485
# 27                             6.998654                    14.479588
# 28                             6.989247                    14.528691
# 29                             8.187919                    14.577793
# 30                             8.021390                    14.626896
# 31                             7.744565                    14.626896
# 32                             7.785235                    14.626896
# 33                                  NaN                    11.671920
# 34                                  NaN                    13.524016
# 35                                  NaN                    13.138841
# 36                                  NaN                    13.495076
# 37                                  NaN                    13.140280
# 38                                  NaN                    13.300239
# 39                                  NaN                    13.046476
# 40                                  NaN                    13.300239
# 41                                  NaN                    13.300239
# 42                                  NaN                    13.300239
# 43                                  NaN                    13.300239
# 44                             3.041825                     9.560080
# 45                             2.957486                    10.082500
# 46                             3.079710                    10.604900
# 47                             2.664298                    11.127300
# 48                             2.577320                    11.649700
# 49                             2.013423                    12.172090
#
# Variable  Expected Years of Schooling, female  \
# 0                                    7.226290
# 1                                    7.423227
# 2                                    7.620163
# 3                                    7.817100
# 4                                    7.791942
# 5                                    7.766785
# 6                                    7.741627
# 7                                    7.716470
# 8                                    7.736391
# 9                                    7.736391
# 10                                   7.736391
# 11                                  14.115110
# 12                                  15.027850
# 13                                  15.429990
# 14                                  15.783350
# 15                                  15.601780
# 16                                  15.405060
# 17                                  15.511230
# 18                                  15.501030
# 19                                  15.671730
# 20                                  15.314140
# 21                                  15.314140
# 22                                  14.577490
# 23                                  14.577490
# 24                                  14.577490
# 25                                  14.705617
# 26                                  14.833745
# 27                                  14.961873
# 28                                  15.090000
# 29                                  15.218128
# 30                                  15.346255
# 31                                  15.346255
# 32                                  15.346255
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                   7.286790
# 45                                   8.137600
# 46                                   8.988400
# 47                                   9.839300
# 48                                  10.690100
# 49                                  11.540933
#
# Variable  Expected Years of Schooling, male  Gender Development Index  ...  \
# 0                                 11.228550                     0.642  ...
# 1                                 11.622750                     0.649  ...
# 2                                 12.016950                     0.659  ...
# 3                                 12.411150                     0.630  ...
# 4                                 12.448320                     0.673  ...
# 5                                 12.485490                     0.682  ...
# 6                                 12.522660                     0.703  ...
# 7                                 12.559830                     0.710  ...
# 8                                 12.672189                     0.712  ...
# 9                                 12.672189                     0.689  ...
# 10                                12.672189                     0.681  ...
# 11                                13.417510                     0.964  ...
# 12                                14.188410                     0.974  ...
# 13                                14.481150                     0.968  ...
# 14                                14.783360                     0.968  ...
# 15                                14.609360                     0.984  ...
# 16                                14.259330                     0.988  ...
# 17                                14.179940                     0.991  ...
# 18                                13.956830                     0.997  ...
# 19                                14.033500                     1.002  ...
# 20                                13.651870                     1.006  ...
# 21                                13.651870                     1.007  ...
# 22                                14.093840                     0.846  ...
# 23                                14.093840                     0.854  ...
# 24                                14.093840                     0.857  ...
# 25                                14.072587                     0.860  ...
# 26                                14.051335                     0.865  ...
# 27                                14.030083                     0.871  ...
# 28                                14.008831                     0.873  ...
# 29                                13.987579                     0.876  ...
# 30                                13.966327                     0.880  ...
# 31                                13.966327                     0.877  ...
# 32                                13.966327                     0.880  ...
# 33                                      NaN                       NaN  ...
# 34                                      NaN                       NaN  ...
# 35                                      NaN                       NaN  ...
# 36                                      NaN                       NaN  ...
# 37                                      NaN                       NaN  ...
# 38                                      NaN                       NaN  ...
# 39                                      NaN                       NaN  ...
# 40                                      NaN                       NaN  ...
# 41                                      NaN                       NaN  ...
# 42                                      NaN                       NaN  ...
# 43                                      NaN                       NaN  ...
# 44                                11.869420                     0.826  ...
# 45                                12.078200                     0.848  ...
# 46                                12.286900                     0.866  ...
# 47                                12.495700                     0.884  ...
# 48                                12.704500                     0.893  ...
# 49                                12.913222                     0.900  ...
#
# Variable  Labour force participation rate, female (% ages 15 and older)  \
# 0                                                    15.454
# 1                                                    15.879
# 2                                                    16.794
# 3                                                    17.749
# 4                                                    18.746
# 5                                                    19.798
# 6                                                    20.887
# 7                                                    21.228
# 8                                                    21.566
# 9                                                    16.189
# 10                                                   14.848
# 11                                                   52.446
# 12                                                   48.778
# 13                                                   43.598
# 14                                                   43.733
# 15                                                   46.898
# 16                                                   49.676
# 17                                                   49.510
# 18                                                   51.189
# 19                                                   52.723
# 20                                                   49.786
# 21                                                   50.733
# 22                                                   14.375
# 23                                                   15.823
# 24                                                   16.602
# 25                                                   15.619
# 26                                                   16.300
# 27                                                   16.945
# 28                                                   16.819
# 29                                                   16.692
# 30                                                   16.600
# 31                                                   15.445
# 32                                                   15.684
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                   74.847
# 45                                                   74.834
# 46                                                   74.833
# 47                                                   74.843
# 48                                                   74.864
# 49                                                   74.882
#
# Variable  Labour force participation rate, male (% ages 15 and older)  \
# 0                                                    76.659
# 1                                                    76.420
# 2                                                    75.588
# 3                                                    74.737
# 4                                                    73.875
# 5                                                    73.045
# 6                                                    72.183
# 7                                                    72.023
# 8                                                    71.863
# 9                                                    65.580
# 10                                                   66.515
# 11                                                   67.483
# 12                                                   65.197
# 13                                                   61.180
# 14                                                   62.984
# 15                                                   63.957
# 16                                                   64.800
# 17                                                   66.440
# 18                                                   67.247
# 19                                                   67.742
# 20                                                   65.631
# 21                                                   66.154
# 22                                                   65.655
# 23                                                   67.900
# 24                                                   69.510
# 25                                                   66.397
# 26                                                   66.832
# 27                                                   66.510
# 28                                                   66.574
# 29                                                   66.626
# 30                                                   66.726
# 31                                                   64.023
# 32                                                   64.480
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                   79.883
# 45                                                   79.922
# 46                                                   79.930
# 47                                                   79.912
# 48                                                   79.865
# 49                                                   79.827
#
# Variable  Life Expectancy at Birth  Life Expectancy at Birth, female  \
# 0                          61.4191                           62.9926
# 1                          61.9230                           63.5135
# 2                          62.4167                           64.0268
# 3                          62.5451                           64.2743
# 4                          62.6587                           64.5759
# 5                          63.1361                           65.0957
# 6                          63.0160                           66.0993
# 7                          63.0810                           66.4576
# 8                          63.5645                           66.6770
# 9                          62.5751                           65.4320
# 10                         61.9824                           65.2791
# 11                         78.0919                           80.7980
# 12                         78.0640                           80.7025
# 13                         78.1226                           80.7812
# 14                         78.4075                           81.0125
# 15                         78.6441                           81.1825
# 16                         78.8602                           81.3771
# 17                         79.0473                           81.5045
# 18                         79.1838                           81.6079
# 19                         79.2825                           81.6658
# 20                         76.9893                           79.6756
# 21                         76.4626                           79.1726
# 22                         74.1234                           75.2364
# 23                         74.2024                           75.4783
# 24                         74.6153                           75.8399
# 25                         75.1100                           76.4667
# 26                         75.6220                           76.8240
# 27                         75.7318                           76.8026
# 28                         75.7428                           76.8212
# 29                         76.0656                           77.2047
# 30                         76.4742                           77.7605
# 31                         74.4528                           75.9125
# 32                         76.3767                           77.9588
# 33                         82.8975                           85.4442
# 34                         82.9166                           85.4442
# 35                         82.9343                           85.4442
# 36                         82.9483                           85.4442
# 37                         82.9534                           85.4340
# 38                         82.9671                           85.4340
# 39                         82.9803                           85.4340
# 40                         82.9923                           85.4340
# 41                         83.0039                           85.4340
# 42                         79.0234                           83.1922
# 43                         80.3684                           84.3238
# 44                         57.5961                           59.8693
# 45                         58.6231                           61.0236
# 46                         59.3074                           61.6844
# 47                         60.0397                           62.4717
# 48                         60.6546                           63.0944
# 49                         61.0923                           63.4338
#
# Variable  Life Expectancy at Birth, male  \
# 0                                59.8254
# 1                                60.3173
# 2                                60.7915
# 3                                60.8119
# 4                                60.7597
# 5                                61.1934
# 6                                60.1049
# 7                                59.9231
# 8                                60.6191
# 9                                59.8662
# 10                               58.9147
# 11                               75.6932
# 12                               75.7302
# 13                               75.7863
# 14                               76.1142
# 15                               76.4036
# 16                               76.6392
# 17                               76.8729
# 18                               77.0366
# 19                               77.1679
# 20                               74.6325
# 21                               74.0869
# 22                               73.0404
# 23                               72.9705
# 24                               73.4301
# 25                               73.8032
# 26                               74.4564
# 27                               74.6927
# 28                               74.6997
# 29                               74.9662
# 30                               75.2382
# 31                               73.0821
# 32                               74.8787
# 33                               80.5240
# 34                               80.5546
# 35                               80.5852
# 36                               80.6157
# 37                               80.6462
# 38                               80.6868
# 39                               80.7172
# 40                               80.7477
# 41                               80.7781
# 42                               75.7629
# 43                               77.1723
# 44                               55.3139
# 45                               56.2197
# 46                               56.9254
# 47                               57.6063
# 48                               58.2133
# 49                               58.7410
#
# Variable  Maternal Mortality Ratio (deaths per 100,000 live births)  \
# 0                                                     905.0
# 1                                                     858.0
# 2                                                     810.0
# 3                                                     786.0
# 4                                                     701.0
# 5                                                     673.0
# 6                                                     638.0
# 7                                                     638.0
# 8                                                     638.0
# 9                                                     638.0
# 10                                                    638.0
# 11                                                     22.0
# 12                                                     17.0
# 13                                                     16.0
# 14                                                     16.0
# 15                                                     15.0
# 16                                                     16.0
# 17                                                     15.0
# 18                                                     15.0
# 19                                                     15.0
# 20                                                     15.0
# 21                                                     15.0
# 22                                                    116.0
# 23                                                    116.0
# 24                                                    115.0
# 25                                                    114.0
# 26                                                    114.0
# 27                                                    113.0
# 28                                                    112.0
# 29                                                    112.0
# 30                                                    112.0
# 31                                                    112.0
# 32                                                    112.0
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                    300.0
# 45                                                    281.0
# 46                                                    269.0
# 47                                                    258.0
# 48                                                    251.0
# 49                                                    246.0
#
# Variable  Mean Years of Schooling  Mean Years of Schooling, female  \
# 0                        2.157332                         1.011199
# 1                        2.209473                         1.076438
# 2                        2.261614                         1.141677
# 3                        2.313755                         1.206915
# 4                        2.365896                         1.272154
# 5                        2.463660                         1.430358
# 6                        2.561425                         1.588562
# 7                        2.659189                         1.746765
# 8                        2.756953                         1.904969
# 9                        2.854718                         2.063173
# 10                       2.985070                         2.311080
# 11                       9.801700                         9.396470
# 12                      10.025110                         9.832490
# 13                      10.196281                        10.077895
# 14                      10.370374                        10.329424
# 15                      10.547439                        10.587232
# 16                      10.727528                        10.851474
# 17                      10.910692                        11.122311
# 18                      11.096983                        11.399908
# 19                      11.286455                        11.684433
# 20                      11.286455                        11.684433
# 21                      11.286455                        11.684433
# 22                       7.566753                         6.860750
# 23                       7.627817                         6.964458
# 24                       7.689373                         7.069733
# 25                       7.751426                         7.176600
# 26                       7.813980                         7.285083
# 27                       7.877039                         7.395205
# 28                       7.940606                         7.506991
# 29                       8.004687                         7.620468
# 30                       8.069284                         7.735660
# 31                       8.069284                         7.735660
# 32                       8.069284                         7.735660
# 33                      10.558107                        10.506660
# 34                      10.587085                        10.534280
# 35                      10.616062                        10.561900
# 36                      10.645040                        10.589520
# 37                      10.573280                        10.512780
# 38                      10.556100                        10.490550
# 39                      10.555773                        10.487412
# 40                      10.555446                        10.484275
# 41                      10.555120                        10.481139
# 42                      10.555120                        10.481139
# 43                      10.555120                        10.481139
# 44                       3.869118                         2.947890
# 45                       3.909642                         3.009297
# 46                       3.950166                         3.070703
# 47                       3.990690                         3.132110
# 48                       4.704040                         3.657993
# 49                       5.417391                         4.183876
#
# Variable  Mean Years of Schooling, male  Overall loss (%)
# 0                              2.755239         30.921053
# 1                              2.820266         30.686695
# 2                              2.885293               NaN
# 3                              2.950319               NaN
# 4                              3.015346               NaN
# 5                              3.082470               NaN
# 6                              3.149594               NaN
# 7                              3.216718               NaN
# 8                              3.283843               NaN
# 9                              3.350967               NaN
# 10                             3.401310               NaN
# 11                            10.221640         12.663185
# 12                            10.238510         10.539846
# 13                            10.333292         10.318471
# 14                            10.428951         10.227273
# 15                            10.525496         10.188679
# 16                            10.622934         10.150376
# 17                            10.721275         10.224439
# 18                            10.820526         10.669975
# 19                            10.920695         10.617284
# 20                            10.920695         10.705290
# 21                            10.920695         10.804020
# 22                             8.269175               NaN
# 23                             8.290142               NaN
# 24                             8.311163         20.519836
# 25                             8.332237         20.408163
# 26                             8.353365         20.405405
# 27                             8.374546         20.323015
# 28                             8.395781         20.295699
# 29                             8.417069         20.134228
# 30                             8.438412         19.919786
# 31                             8.438412         19.836957
# 32                             8.438412         19.731544
# 33                            10.609950               NaN
# 34                            10.640590               NaN
# 35                            10.671230               NaN
# 36                            10.701870               NaN
# 37                            10.633620               NaN
# 38                            10.621080               NaN
# 39                            10.623379               NaN
# 40                            10.625678               NaN
# 41                            10.627977               NaN
# 42                            10.627977               NaN
# 43                            10.627977               NaN
# 44                             4.899406               NaN
# 45                             4.916704               NaN
# 46                             4.934002               NaN
# 47                             4.951300               NaN
# 48                             5.922784         32.130584
# 49                             6.894269         31.711409
#
# [50 rows x 32 columns]

# %%
df_wide.head(50)
# Out:
# Variable      Country  Year  \
# 0         Afghanistan  2011
# 1         Afghanistan  2012
# 2         Afghanistan  2013
# 3         Afghanistan  2014
# 4         Afghanistan  2015
# 5         Afghanistan  2016
# 6         Afghanistan  2017
# 7         Afghanistan  2018
# 8         Afghanistan  2019
# 9         Afghanistan  2020
# 10        Afghanistan  2021
# 11            Albania  2011
# 12            Albania  2012
# 13            Albania  2013
# 14            Albania  2014
# 15            Albania  2015
# 16            Albania  2016
# 17            Albania  2017
# 18            Albania  2018
# 19            Albania  2019
# 20            Albania  2020
# 21            Albania  2021
# 22            Algeria  2011
# 23            Algeria  2012
# 24            Algeria  2013
# 25            Algeria  2014
# 26            Algeria  2015
# 27            Algeria  2016
# 28            Algeria  2017
# 29            Algeria  2018
# 30            Algeria  2019
# 31            Algeria  2020
# 32            Algeria  2021
# 33            Andorra  2011
# 34            Andorra  2012
# 35            Andorra  2013
# 36            Andorra  2014
# 37            Andorra  2015
# 38            Andorra  2016
# 39            Andorra  2017
# 40            Andorra  2018
# 41            Andorra  2019
# 42            Andorra  2020
# 43            Andorra  2021
# 44             Angola  2011
# 45             Angola  2012
# 46             Angola  2013
# 47             Angola  2014
# 48             Angola  2015
# 49             Angola  2016
#
# Variable  Adolescent Birth Rate (births per 1,000 women ages 15-19)  \
# 0                                                   116.454
# 1                                                   111.286
# 2                                                   106.537
# 3                                                   101.454
# 4                                                    97.415
# 5                                                    94.018
# 6                                                    90.342
# 7                                                    88.431
# 8                                                    86.803
# 9                                                    84.296
# 10                                                   82.565
# 11                                                   20.692
# 12                                                   20.909
# 13                                                   20.865
# 14                                                   20.942
# 15                                                   20.276
# 16                                                   18.171
# 17                                                   16.585
# 18                                                   15.580
# 19                                                   15.013
# 20                                                   14.672
# 21                                                   14.517
# 22                                                   11.134
# 23                                                   11.950
# 24                                                   12.684
# 25                                                   12.771
# 26                                                   11.888
# 27                                                   12.731
# 28                                                   12.872
# 29                                                   12.654
# 30                                                   12.303
# 31                                                   12.057
# 32                                                   11.714
# 33                                                    9.574
# 34                                                    8.414
# 35                                                    6.989
# 36                                                    6.925
# 37                                                    7.402
# 38                                                    7.176
# 39                                                    6.404
# 40                                                    6.080
# 41                                                    5.985
# 42                                                    6.091
# 43                                                    5.887
# 44                                                  159.295
# 45                                                  156.557
# 46                                                  153.345
# 47                                                  151.093
# 48                                                  148.074
# 49                                                  146.135
#
# Variable  Coefficient of human inequality  Difference from HDI rank  \
# 0                               29.495694                       NaN
# 1                               29.208713                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
# 5                                     NaN                       NaN
# 6                                     NaN                       NaN
# 7                                     NaN                       NaN
# 8                                     NaN                       NaN
# 9                                     NaN                       NaN
# 10                                    NaN                       5.0
# 11                              12.624666                       NaN
# 12                              10.429779                       NaN
# 13                              10.298332                       NaN
# 14                              10.198068                       NaN
# 15                              10.133330                       NaN
# 16                              10.100487                       NaN
# 17                              10.233289                       NaN
# 18                              10.554499                       NaN
# 19                              10.589337                       NaN
# 20                              10.727042                       NaN
# 21                              10.767685                      28.0
# 22                                    NaN                       NaN
# 23                                    NaN                       NaN
# 24                              19.842188                       NaN
# 25                              19.776358                       NaN
# 26                              19.713805                       NaN
# 27                              19.643913                       NaN
# 28                              19.568293                       NaN
# 29                              19.480038                       NaN
# 30                              19.297498                       NaN
# 31                              19.194810                       NaN
# 32                              19.072875                      16.0
# 33                                    NaN                       NaN
# 34                                    NaN                       NaN
# 35                                    NaN                       NaN
# 36                                    NaN                       NaN
# 37                                    NaN                       NaN
# 38                                    NaN                       NaN
# 39                                    NaN                       NaN
# 40                                    NaN                       NaN
# 41                                    NaN                       NaN
# 42                                    NaN                       NaN
# 43                                    NaN                       NaN
# 44                                    NaN                       NaN
# 45                                    NaN                       NaN
# 46                                    NaN                       NaN
# 47                                    NaN                       NaN
# 48                              32.040235                       NaN
# 49                              31.708308                       NaN
#
# Variable  Difference from HDI value (%)  Expected Years of Schooling  \
# 0                              1.315789                     9.278810
# 1                              1.072961                     9.577323
# 2                              1.054852                     9.875836
# 3                              1.043841                    10.174350
# 4                              0.836820                    10.180150
# 5                              0.831601                    10.185950
# 6                              0.829876                    10.191750
# 7                              0.828157                    10.197550
# 8                              0.819672                    10.263844
# 9                              0.828157                    10.263844
# 10                             0.836820                    10.263844
# 11                             7.049608                    13.748450
# 12                             6.940874                    14.586650
# 13                             6.624204                    14.925640
# 14                             7.575758                    15.252420
# 15                             7.044025                    15.076300
# 16                             7.769424                    14.804600
# 17                             8.104738                    14.816130
# 18                             7.196030                    14.695620
# 19                             7.283951                    14.818920
# 20                             7.178841                    14.448000
# 21                             7.160804                    14.448000
# 22                             6.877579                    14.332280
# 23                             6.858711                    14.332280
# 24                             6.839945                    14.332280
# 25                             7.074830                    14.381383
# 26                             7.162162                    14.430485
# 27                             6.998654                    14.479588
# 28                             6.989247                    14.528691
# 29                             8.187919                    14.577793
# 30                             8.021390                    14.626896
# 31                             7.744565                    14.626896
# 32                             7.785235                    14.626896
# 33                                  NaN                    11.671920
# 34                                  NaN                    13.524016
# 35                                  NaN                    13.138841
# 36                                  NaN                    13.495076
# 37                                  NaN                    13.140280
# 38                                  NaN                    13.300239
# 39                                  NaN                    13.046476
# 40                                  NaN                    13.300239
# 41                                  NaN                    13.300239
# 42                                  NaN                    13.300239
# 43                                  NaN                    13.300239
# 44                             3.041825                     9.560080
# 45                             2.957486                    10.082500
# 46                             3.079710                    10.604900
# 47                             2.664298                    11.127300
# 48                             2.577320                    11.649700
# 49                             2.013423                    12.172090
#
# Variable  Expected Years of Schooling, female  \
# 0                                    7.226290
# 1                                    7.423227
# 2                                    7.620163
# 3                                    7.817100
# 4                                    7.791942
# 5                                    7.766785
# 6                                    7.741627
# 7                                    7.716470
# 8                                    7.736391
# 9                                    7.736391
# 10                                   7.736391
# 11                                  14.115110
# 12                                  15.027850
# 13                                  15.429990
# 14                                  15.783350
# 15                                  15.601780
# 16                                  15.405060
# 17                                  15.511230
# 18                                  15.501030
# 19                                  15.671730
# 20                                  15.314140
# 21                                  15.314140
# 22                                  14.577490
# 23                                  14.577490
# 24                                  14.577490
# 25                                  14.705617
# 26                                  14.833745
# 27                                  14.961873
# 28                                  15.090000
# 29                                  15.218128
# 30                                  15.346255
# 31                                  15.346255
# 32                                  15.346255
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                   7.286790
# 45                                   8.137600
# 46                                   8.988400
# 47                                   9.839300
# 48                                  10.690100
# 49                                  11.540933
#
# Variable  Expected Years of Schooling, male  Gender Development Index  ...  \
# 0                                 11.228550                     0.642  ...
# 1                                 11.622750                     0.649  ...
# 2                                 12.016950                     0.659  ...
# 3                                 12.411150                     0.630  ...
# 4                                 12.448320                     0.673  ...
# 5                                 12.485490                     0.682  ...
# 6                                 12.522660                     0.703  ...
# 7                                 12.559830                     0.710  ...
# 8                                 12.672189                     0.712  ...
# 9                                 12.672189                     0.689  ...
# 10                                12.672189                     0.681  ...
# 11                                13.417510                     0.964  ...
# 12                                14.188410                     0.974  ...
# 13                                14.481150                     0.968  ...
# 14                                14.783360                     0.968  ...
# 15                                14.609360                     0.984  ...
# 16                                14.259330                     0.988  ...
# 17                                14.179940                     0.991  ...
# 18                                13.956830                     0.997  ...
# 19                                14.033500                     1.002  ...
# 20                                13.651870                     1.006  ...
# 21                                13.651870                     1.007  ...
# 22                                14.093840                     0.846  ...
# 23                                14.093840                     0.854  ...
# 24                                14.093840                     0.857  ...
# 25                                14.072587                     0.860  ...
# 26                                14.051335                     0.865  ...
# 27                                14.030083                     0.871  ...
# 28                                14.008831                     0.873  ...
# 29                                13.987579                     0.876  ...
# 30                                13.966327                     0.880  ...
# 31                                13.966327                     0.877  ...
# 32                                13.966327                     0.880  ...
# 33                                      NaN                       NaN  ...
# 34                                      NaN                       NaN  ...
# 35                                      NaN                       NaN  ...
# 36                                      NaN                       NaN  ...
# 37                                      NaN                       NaN  ...
# 38                                      NaN                       NaN  ...
# 39                                      NaN                       NaN  ...
# 40                                      NaN                       NaN  ...
# 41                                      NaN                       NaN  ...
# 42                                      NaN                       NaN  ...
# 43                                      NaN                       NaN  ...
# 44                                11.869420                     0.826  ...
# 45                                12.078200                     0.848  ...
# 46                                12.286900                     0.866  ...
# 47                                12.495700                     0.884  ...
# 48                                12.704500                     0.893  ...
# 49                                12.913222                     0.900  ...
#
# Variable  Labour force participation rate, female (% ages 15 and older)  \
# 0                                                    15.454
# 1                                                    15.879
# 2                                                    16.794
# 3                                                    17.749
# 4                                                    18.746
# 5                                                    19.798
# 6                                                    20.887
# 7                                                    21.228
# 8                                                    21.566
# 9                                                    16.189
# 10                                                   14.848
# 11                                                   52.446
# 12                                                   48.778
# 13                                                   43.598
# 14                                                   43.733
# 15                                                   46.898
# 16                                                   49.676
# 17                                                   49.510
# 18                                                   51.189
# 19                                                   52.723
# 20                                                   49.786
# 21                                                   50.733
# 22                                                   14.375
# 23                                                   15.823
# 24                                                   16.602
# 25                                                   15.619
# 26                                                   16.300
# 27                                                   16.945
# 28                                                   16.819
# 29                                                   16.692
# 30                                                   16.600
# 31                                                   15.445
# 32                                                   15.684
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                   74.847
# 45                                                   74.834
# 46                                                   74.833
# 47                                                   74.843
# 48                                                   74.864
# 49                                                   74.882
#
# Variable  Labour force participation rate, male (% ages 15 and older)  \
# 0                                                    76.659
# 1                                                    76.420
# 2                                                    75.588
# 3                                                    74.737
# 4                                                    73.875
# 5                                                    73.045
# 6                                                    72.183
# 7                                                    72.023
# 8                                                    71.863
# 9                                                    65.580
# 10                                                   66.515
# 11                                                   67.483
# 12                                                   65.197
# 13                                                   61.180
# 14                                                   62.984
# 15                                                   63.957
# 16                                                   64.800
# 17                                                   66.440
# 18                                                   67.247
# 19                                                   67.742
# 20                                                   65.631
# 21                                                   66.154
# 22                                                   65.655
# 23                                                   67.900
# 24                                                   69.510
# 25                                                   66.397
# 26                                                   66.832
# 27                                                   66.510
# 28                                                   66.574
# 29                                                   66.626
# 30                                                   66.726
# 31                                                   64.023
# 32                                                   64.480
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                   79.883
# 45                                                   79.922
# 46                                                   79.930
# 47                                                   79.912
# 48                                                   79.865
# 49                                                   79.827
#
# Variable  Life Expectancy at Birth  Life Expectancy at Birth, female  \
# 0                          61.4191                           62.9926
# 1                          61.9230                           63.5135
# 2                          62.4167                           64.0268
# 3                          62.5451                           64.2743
# 4                          62.6587                           64.5759
# 5                          63.1361                           65.0957
# 6                          63.0160                           66.0993
# 7                          63.0810                           66.4576
# 8                          63.5645                           66.6770
# 9                          62.5751                           65.4320
# 10                         61.9824                           65.2791
# 11                         78.0919                           80.7980
# 12                         78.0640                           80.7025
# 13                         78.1226                           80.7812
# 14                         78.4075                           81.0125
# 15                         78.6441                           81.1825
# 16                         78.8602                           81.3771
# 17                         79.0473                           81.5045
# 18                         79.1838                           81.6079
# 19                         79.2825                           81.6658
# 20                         76.9893                           79.6756
# 21                         76.4626                           79.1726
# 22                         74.1234                           75.2364
# 23                         74.2024                           75.4783
# 24                         74.6153                           75.8399
# 25                         75.1100                           76.4667
# 26                         75.6220                           76.8240
# 27                         75.7318                           76.8026
# 28                         75.7428                           76.8212
# 29                         76.0656                           77.2047
# 30                         76.4742                           77.7605
# 31                         74.4528                           75.9125
# 32                         76.3767                           77.9588
# 33                         82.8975                           85.4442
# 34                         82.9166                           85.4442
# 35                         82.9343                           85.4442
# 36                         82.9483                           85.4442
# 37                         82.9534                           85.4340
# 38                         82.9671                           85.4340
# 39                         82.9803                           85.4340
# 40                         82.9923                           85.4340
# 41                         83.0039                           85.4340
# 42                         79.0234                           83.1922
# 43                         80.3684                           84.3238
# 44                         57.5961                           59.8693
# 45                         58.6231                           61.0236
# 46                         59.3074                           61.6844
# 47                         60.0397                           62.4717
# 48                         60.6546                           63.0944
# 49                         61.0923                           63.4338
#
# Variable  Life Expectancy at Birth, male  \
# 0                                59.8254
# 1                                60.3173
# 2                                60.7915
# 3                                60.8119
# 4                                60.7597
# 5                                61.1934
# 6                                60.1049
# 7                                59.9231
# 8                                60.6191
# 9                                59.8662
# 10                               58.9147
# 11                               75.6932
# 12                               75.7302
# 13                               75.7863
# 14                               76.1142
# 15                               76.4036
# 16                               76.6392
# 17                               76.8729
# 18                               77.0366
# 19                               77.1679
# 20                               74.6325
# 21                               74.0869
# 22                               73.0404
# 23                               72.9705
# 24                               73.4301
# 25                               73.8032
# 26                               74.4564
# 27                               74.6927
# 28                               74.6997
# 29                               74.9662
# 30                               75.2382
# 31                               73.0821
# 32                               74.8787
# 33                               80.5240
# 34                               80.5546
# 35                               80.5852
# 36                               80.6157
# 37                               80.6462
# 38                               80.6868
# 39                               80.7172
# 40                               80.7477
# 41                               80.7781
# 42                               75.7629
# 43                               77.1723
# 44                               55.3139
# 45                               56.2197
# 46                               56.9254
# 47                               57.6063
# 48                               58.2133
# 49                               58.7410
#
# Variable  Maternal Mortality Ratio (deaths per 100,000 live births)  \
# 0                                                     905.0
# 1                                                     858.0
# 2                                                     810.0
# 3                                                     786.0
# 4                                                     701.0
# 5                                                     673.0
# 6                                                     638.0
# 7                                                     638.0
# 8                                                     638.0
# 9                                                     638.0
# 10                                                    638.0
# 11                                                     22.0
# 12                                                     17.0
# 13                                                     16.0
# 14                                                     16.0
# 15                                                     15.0
# 16                                                     16.0
# 17                                                     15.0
# 18                                                     15.0
# 19                                                     15.0
# 20                                                     15.0
# 21                                                     15.0
# 22                                                    116.0
# 23                                                    116.0
# 24                                                    115.0
# 25                                                    114.0
# 26                                                    114.0
# 27                                                    113.0
# 28                                                    112.0
# 29                                                    112.0
# 30                                                    112.0
# 31                                                    112.0
# 32                                                    112.0
# 33                                                      NaN
# 34                                                      NaN
# 35                                                      NaN
# 36                                                      NaN
# 37                                                      NaN
# 38                                                      NaN
# 39                                                      NaN
# 40                                                      NaN
# 41                                                      NaN
# 42                                                      NaN
# 43                                                      NaN
# 44                                                    300.0
# 45                                                    281.0
# 46                                                    269.0
# 47                                                    258.0
# 48                                                    251.0
# 49                                                    246.0
#
# Variable  Mean Years of Schooling  Mean Years of Schooling, female  \
# 0                        2.157332                         1.011199
# 1                        2.209473                         1.076438
# 2                        2.261614                         1.141677
# 3                        2.313755                         1.206915
# 4                        2.365896                         1.272154
# 5                        2.463660                         1.430358
# 6                        2.561425                         1.588562
# 7                        2.659189                         1.746765
# 8                        2.756953                         1.904969
# 9                        2.854718                         2.063173
# 10                       2.985070                         2.311080
# 11                       9.801700                         9.396470
# 12                      10.025110                         9.832490
# 13                      10.196281                        10.077895
# 14                      10.370374                        10.329424
# 15                      10.547439                        10.587232
# 16                      10.727528                        10.851474
# 17                      10.910692                        11.122311
# 18                      11.096983                        11.399908
# 19                      11.286455                        11.684433
# 20                      11.286455                        11.684433
# 21                      11.286455                        11.684433
# 22                       7.566753                         6.860750
# 23                       7.627817                         6.964458
# 24                       7.689373                         7.069733
# 25                       7.751426                         7.176600
# 26                       7.813980                         7.285083
# 27                       7.877039                         7.395205
# 28                       7.940606                         7.506991
# 29                       8.004687                         7.620468
# 30                       8.069284                         7.735660
# 31                       8.069284                         7.735660
# 32                       8.069284                         7.735660
# 33                      10.558107                        10.506660
# 34                      10.587085                        10.534280
# 35                      10.616062                        10.561900
# 36                      10.645040                        10.589520
# 37                      10.573280                        10.512780
# 38                      10.556100                        10.490550
# 39                      10.555773                        10.487412
# 40                      10.555446                        10.484275
# 41                      10.555120                        10.481139
# 42                      10.555120                        10.481139
# 43                      10.555120                        10.481139
# 44                       3.869118                         2.947890
# 45                       3.909642                         3.009297
# 46                       3.950166                         3.070703
# 47                       3.990690                         3.132110
# 48                       4.704040                         3.657993
# 49                       5.417391                         4.183876
#
# Variable  Mean Years of Schooling, male  Overall loss (%)
# 0                              2.755239         30.921053
# 1                              2.820266         30.686695
# 2                              2.885293               NaN
# 3                              2.950319               NaN
# 4                              3.015346               NaN
# 5                              3.082470               NaN
# 6                              3.149594               NaN
# 7                              3.216718               NaN
# 8                              3.283843               NaN
# 9                              3.350967               NaN
# 10                             3.401310               NaN
# 11                            10.221640         12.663185
# 12                            10.238510         10.539846
# 13                            10.333292         10.318471
# 14                            10.428951         10.227273
# 15                            10.525496         10.188679
# 16                            10.622934         10.150376
# 17                            10.721275         10.224439
# 18                            10.820526         10.669975
# 19                            10.920695         10.617284
# 20                            10.920695         10.705290
# 21                            10.920695         10.804020
# 22                             8.269175               NaN
# 23                             8.290142               NaN
# 24                             8.311163         20.519836
# 25                             8.332237         20.408163
# 26                             8.353365         20.405405
# 27                             8.374546         20.323015
# 28                             8.395781         20.295699
# 29                             8.417069         20.134228
# 30                             8.438412         19.919786
# 31                             8.438412         19.836957
# 32                             8.438412         19.731544
# 33                            10.609950               NaN
# 34                            10.640590               NaN
# 35                            10.671230               NaN
# 36                            10.701870               NaN
# 37                            10.633620               NaN
# 38                            10.621080               NaN
# 39                            10.623379               NaN
# 40                            10.625678               NaN
# 41                            10.627977               NaN
# 42                            10.627977               NaN
# 43                            10.627977               NaN
# 44                             4.899406               NaN
# 45                             4.916704               NaN
# 46                             4.934002               NaN
# 47                             4.951300               NaN
# 48                             5.922784         32.130584
# 49                             6.894269         31.711409
#
# [50 rows x 32 columns]

# %%
df_wide.shape
# Out:
# (2145, 32)

# %%
df_wide.isna().sum()
# Out:
# Variable
# Country                                                             0
# Year                                                                0
# Adolescent Birth Rate (births per 1,000 women ages 15-19)           0
# Coefficient of human inequality                                   522
# Difference from HDI rank                                         1990
# Difference from HDI value (%)                                     440
# Expected Years of Schooling                                        33
# Expected Years of Schooling, female                                77
# Expected Years of Schooling, male                                  77
# Gender Development Index                                          259
# Gender Inequality Index                                           290
# Gross National Income Per Capita                                   22
# Gross National Income Per Capita, female                          176
# Gross National Income Per Capita, male                            176
# HDI Rank                                                         1954
# HDI female                                                        259
# HDI male                                                          259
# Human Development Index                                            51
# Inequality in eduation                                            303
# Inequality in income                                              456
# Inequality in life expectancy                                       0
# Inequality-adjusted Human Development Index                       522
# Labour force participation rate, female (% ages 15 and older)     165
# Labour force participation rate, male (% ages 15 and older)       165
# Life Expectancy at Birth                                            0
# Life Expectancy at Birth, female                                    0
# Life Expectancy at Birth, male                                      0
# Maternal Mortality Ratio (deaths per 100,000 live births)         121
# Mean Years of Schooling                                            51
# Mean Years of Schooling, female                                   189
# Mean Years of Schooling, male                                     189
# Overall loss (%)                                                  522
# dtype: int64

# %%
# DROPPING MORE UNNECESSARY COLUMNS
df_wide.drop(['Coefficient of human inequality',
         'Difference from HDI rank',
         'Difference from HDI value (%)',
         'HDI Rank',
         'Inequality-adjusted Human Development Index',
         ], 
        axis=1, 
        inplace=True)

# %%
df_wide.dtypes
# Out:
# Variable
# Country                                                           object
# Year                                                               int64
# Adolescent Birth Rate (births per 1,000 women ages 15-19)        float64
# Expected Years of Schooling                                      float64
# Expected Years of Schooling, female                              float64
# Expected Years of Schooling, male                                float64
# Gender Development Index                                         float64
# Gender Inequality Index                                          float64
# Gross National Income Per Capita                                 float64
# Gross National Income Per Capita, female                         float64
# Gross National Income Per Capita, male                           float64
# HDI female                                                       float64
# HDI male                                                         float64
# Human Development Index                                          float64
# Inequality in eduation                                           float64
# Inequality in income                                             float64
# Inequality in life expectancy                                    float64
# Labour force participation rate, female (% ages 15 and older)    float64
# Labour force participation rate, male (% ages 15 and older)      float64
# Life Expectancy at Birth                                         float64
# Life Expectancy at Birth, female                                 float64
# Life Expectancy at Birth, male                                   float64
# Maternal Mortality Ratio (deaths per 100,000 live births)        float64
# Mean Years of Schooling                                          float64
# Mean Years of Schooling, female                                  float64
# Mean Years of Schooling, male                                    float64
# Overall loss (%)                                                 float64
# dtype: object

# %%
# df_wide.columns = df_wide.columns.str.replace(' ', '_')

# %%
# CONVERTING VALUES INTO NUMERICAL
for col in df_wide.columns:
    if col != 'Country':
        df_wide[col] = df_wide[col].astype(float)

df_wide.dtypes
# Out:
# Variable
# Country                                                           object
# Year                                                             float64
# Adolescent Birth Rate (births per 1,000 women ages 15-19)        float64
# Expected Years of Schooling                                      float64
# Expected Years of Schooling, female                              float64
# Expected Years of Schooling, male                                float64
# Gender Development Index                                         float64
# Gender Inequality Index                                          float64
# Gross National Income Per Capita                                 float64
# Gross National Income Per Capita, female                         float64
# Gross National Income Per Capita, male                           float64
# HDI female                                                       float64
# HDI male                                                         float64
# Human Development Index                                          float64
# Inequality in eduation                                           float64
# Inequality in income                                             float64
# Inequality in life expectancy                                    float64
# Labour force participation rate, female (% ages 15 and older)    float64
# Labour force participation rate, male (% ages 15 and older)      float64
# Life Expectancy at Birth                                         float64
# Life Expectancy at Birth, female                                 float64
# Life Expectancy at Birth, male                                   float64
# Maternal Mortality Ratio (deaths per 100,000 live births)        float64
# Mean Years of Schooling                                          float64
# Mean Years of Schooling, female                                  float64
# Mean Years of Schooling, male                                    float64
# Overall loss (%)                                                 float64
# dtype: object

# %%
df_wide.isna().sum()
# Out:
# Variable
# Country                                                            0
# Year                                                               0
# Adolescent Birth Rate (births per 1,000 women ages 15-19)          0
# Expected Years of Schooling                                       33
# Expected Years of Schooling, female                               77
# Expected Years of Schooling, male                                 77
# Gender Development Index                                         259
# Gender Inequality Index                                          290
# Gross National Income Per Capita                                  22
# Gross National Income Per Capita, female                         176
# Gross National Income Per Capita, male                           176
# HDI female                                                       259
# HDI male                                                         259
# Human Development Index                                           51
# Inequality in eduation                                           303
# Inequality in income                                             456
# Inequality in life expectancy                                      0
# Labour force participation rate, female (% ages 15 and older)    165
# Labour force participation rate, male (% ages 15 and older)      165
# Life Expectancy at Birth                                           0
# Life Expectancy at Birth, female                                   0
# Life Expectancy at Birth, male                                     0
# Maternal Mortality Ratio (deaths per 100,000 live births)        121
# Mean Years of Schooling                                           51
# Mean Years of Schooling, female                                  189
# Mean Years of Schooling, male                                    189
# Overall loss (%)                                                 522
# dtype: int64

# %%
# df_wide.to_csv('../data/raw/formatted_data.csv', index=False)

# %%
# DROPPING MORE UNNECESARY COLUMNS
df_wide.drop(['Gender Development Index',
         'Gross National Income Per Capita',
         'Life Expectancy at Birth',
         'Mean Years of Schooling',
         'Overall loss (%)'
         ], 
        axis=1, 
        inplace=True)

# %%
df_wide.isna().sum()
# Out:
# Variable
# Country                                                            0
# Year                                                               0
# Adolescent Birth Rate (births per 1,000 women ages 15-19)          0
# Expected Years of Schooling                                       33
# Expected Years of Schooling, female                               77
# Expected Years of Schooling, male                                 77
# Gender Inequality Index                                          290
# Gross National Income Per Capita, female                         176
# Gross National Income Per Capita, male                           176
# HDI female                                                       259
# HDI male                                                         259
# Inequality in eduation                                           303
# Inequality in income                                             456
# Inequality in life expectancy                                      0
# Labour force participation rate, female (% ages 15 and older)    165
# Labour force participation rate, male (% ages 15 and older)      165
# Life Expectancy at Birth, female                                   0
# Life Expectancy at Birth, male                                     0
# Maternal Mortality Ratio (deaths per 100,000 live births)        121
# Mean Years of Schooling, female                                  189
# Mean Years of Schooling, male                                    189
# dtype: int64

# %%
# REPLACING MISSING VALUES BY THE MEAN OF THE VALUES AVAILABLE FOR EACH COUNTRY

value_columns = [col for col in df_wide.columns if col not in ['Country', 'Year']]


df_filled = df_wide.copy()


for col in value_columns:
    df_filled[col] = (
        df_filled.groupby("Country")[col]
        .transform(lambda x: x.fillna(x.mean()))
    )

# %%
df_filled.isna().sum()
# Out:
# Variable
# Country                                                            0
# Year                                                               0
# Adolescent Birth Rate (births per 1,000 women ages 15-19)          0
# Expected Years of Schooling                                       22
# Expected Years of Schooling, female                               66
# Expected Years of Schooling, male                                 66
# Gender Inequality Index                                          275
# Gross National Income Per Capita, female                         176
# Gross National Income Per Capita, male                           176
# HDI female                                                       253
# HDI male                                                         253
# Inequality in eduation                                           154
# Inequality in income                                             286
# Inequality in life expectancy                                      0
# Labour force participation rate, female (% ages 15 and older)    165
# Labour force participation rate, male (% ages 15 and older)      165
# Life Expectancy at Birth, female                                   0
# Life Expectancy at Birth, male                                     0
# Maternal Mortality Ratio (deaths per 100,000 live births)        121
# Mean Years of Schooling, female                                  176
# Mean Years of Schooling, male                                    176
# dtype: int64

# %%
df_filled = df_filled.rename(columns={'Adolescent_Birth_Rate_(births_per_1,000_women_ages_15-19)': 'Adolescent_Birth_Rate'})

# %%
df_filled.shape
# Out:
# (2145, 21)

# %%
df_filled.head()
# Out:
# Variable      Country    Year  \
# 0         Afghanistan  2011.0
# 1         Afghanistan  2012.0
# 2         Afghanistan  2013.0
# 3         Afghanistan  2014.0
# 4         Afghanistan  2015.0
#
# Variable  Adolescent Birth Rate (births per 1,000 women ages 15-19)  \
# 0                                                   116.454
# 1                                                   111.286
# 2                                                   106.537
# 3                                                   101.454
# 4                                                    97.415
#
# Variable  Expected Years of Schooling  Expected Years of Schooling, female  \
# 0                            9.278810                             7.226290
# 1                            9.577323                             7.423227
# 2                            9.875836                             7.620163
# 3                           10.174350                             7.817100
# 4                           10.180150                             7.791942
#
# Variable  Expected Years of Schooling, male  Gender Inequality Index  \
# 0                                  11.22855                    0.746
# 1                                  11.62275                    0.738
# 2                                  12.01695                    0.728
# 3                                  12.41115                    0.718
# 4                                  12.44832                    0.706
#
# Variable  Gross National Income Per Capita, female  \
# 0                                       537.516608
# 1                                       585.093023
# 2                                       637.767170
# 3                                       506.139940
# 4                                       681.131699
#
# Variable  Gross National Income Per Capita, male  HDI female  ...  \
# 0                                    3430.983600    0.333528  ...
# 1                                    3633.440859    0.344152  ...
# 2                                    3715.005010    0.354772  ...
# 3                                    3813.313521    0.343466  ...
# 4                                    3489.646939    0.364833  ...
#
# Variable  Inequality in eduation  Inequality in income  \
# 0                       44.82338                10.767
# 1                       44.82338                10.767
# 2                       44.82338                10.767
# 3                       44.82338                10.767
# 4                       45.36517                10.767
#
# Variable  Inequality in life expectancy  \
# 0                             32.896702
# 1                             32.035759
# 2                             31.204229
# 3                             30.735620
# 4                             30.177126
#
# Variable  Labour force participation rate, female (% ages 15 and older)  \
# 0                                                    15.454
# 1                                                    15.879
# 2                                                    16.794
# 3                                                    17.749
# 4                                                    18.746
#
# Variable  Labour force participation rate, male (% ages 15 and older)  \
# 0                                                    76.659
# 1                                                    76.420
# 2                                                    75.588
# 3                                                    74.737
# 4                                                    73.875
#
# Variable  Life Expectancy at Birth, female  Life Expectancy at Birth, male  \
# 0                                  62.9926                         59.8254
# 1                                  63.5135                         60.3173
# 2                                  64.0268                         60.7915
# 3                                  64.2743                         60.8119
# 4                                  64.5759                         60.7597
#
# Variable  Maternal Mortality Ratio (deaths per 100,000 live births)  \
# 0                                                     905.0
# 1                                                     858.0
# 2                                                     810.0
# 3                                                     786.0
# 4                                                     701.0
#
# Variable  Mean Years of Schooling, female  Mean Years of Schooling, male
# 0                                1.011199                       2.755239
# 1                                1.076438                       2.820266
# 2                                1.141677                       2.885293
# 3                                1.206915                       2.950319
# 4                                1.272154                       3.015346
#
# [5 rows x 21 columns]

# %%
missing_by_country = df.groupby('Country').apply(lambda x: x.isna().sum().sum())
missing_by_country = missing_by_country[missing_by_country > 0]
print(missing_by_country)
# Out:
# Country
# Afghanistan              36
# Algeria                  10
# Andorra                 177
# Angola                   16
# Antigua and Barbuda     177
#                        ...
# Tuvalu                  131
# Uganda                    4
# United Arab Emirates     49
# Uzbekistan               45
# Vanuatu                 106
# Length: 89, dtype: int64
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12196\3084613887.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_by_country = df.groupby('Country').apply(lambda x: x.isna().sum().sum())

# %%
df_filled['Year'] = pd.to_datetime(df_filled['Year'], format='%Y')

# %%
#  RESHAPING THE DATAFRAME FOR SQL AND CORRECT GENDER ANALYSIS

df_melted2 = df_filled.melt(id_vars=['Country', 'Year'], var_name='Indicator', value_name='Value')


df_melted2['Sex'] = df_melted2['Indicator'].apply(
    lambda x: 'female' if 'female' in x.lower() else (
        'male' if 'male' in x.lower() else None
    )
)


df_melted2['Sex'] = df_melted2.apply(
    lambda row: (
        'female' if 'female' in row['Indicator'].lower()
        else 'male' if 'male' in row['Indicator'].lower()
        else 'General'
    ) if pd.isna(row['Sex']) else row['Sex'],
    axis=1
)


df_melted2['Indicator'] = (
    df_melted2['Indicator']
    .str.replace(r'[_,-]?\s?(female|male)$', '', regex=True)
    .str.strip()
)


final = df_melted2[['Country', 'Year', 'Indicator', 'Sex', 'Value']]

# %%
(final['Sex'].isna().sum())
# Out:
# np.int64(0)

# %%
final.loc[
    (final['Indicator'].str.startswith("Adolescent Birth Rate")) &
    (final['Sex'] == 'General'),
    'Sex'
] = 'female'

# %%
final[final['Indicator'].str.startswith("Adolescent Birth Rate")]['Sex'].value_counts()
# Out:
# Sex
# female    2145
# Name: count, dtype: int64

# %%
final.tail(50)
# Out:
#          Country       Year                Indicator   Sex      Value
# 40705  Venezuela 2016-01-01  Mean Years of Schooling  male  10.015460
# 40706  Venezuela 2017-01-01  Mean Years of Schooling  male  10.285864
# 40707  Venezuela 2018-01-01  Mean Years of Schooling  male  10.563568
# 40708  Venezuela 2019-01-01  Mean Years of Schooling  male  10.848770
# 40709  Venezuela 2020-01-01  Mean Years of Schooling  male  10.848770
# 40710  Venezuela 2021-01-01  Mean Years of Schooling  male  10.848770
# 40711   Viet Nam 2011-01-01  Mean Years of Schooling  male   8.238050
# 40712   Viet Nam 2012-01-01  Mean Years of Schooling  male   8.299185
# 40713   Viet Nam 2013-01-01  Mean Years of Schooling  male   8.360320
# 40714   Viet Nam 2014-01-01  Mean Years of Schooling  male   8.421455
# 40715   Viet Nam 2015-01-01  Mean Years of Schooling  male   8.482590
# 40716   Viet Nam 2016-01-01  Mean Years of Schooling  male   8.543725
# 40717   Viet Nam 2017-01-01  Mean Years of Schooling  male   8.604860
# 40718   Viet Nam 2018-01-01  Mean Years of Schooling  male   8.665995
# 40719   Viet Nam 2019-01-01  Mean Years of Schooling  male   8.727130
# 40720   Viet Nam 2020-01-01  Mean Years of Schooling  male   8.727130
# 40721   Viet Nam 2021-01-01  Mean Years of Schooling  male   8.727130
# 40722      Yemen 2011-01-01  Mean Years of Schooling  male   4.016000
# 40723      Yemen 2012-01-01  Mean Years of Schooling  male   4.222000
# 40724      Yemen 2013-01-01  Mean Years of Schooling  male   4.222000
# 40725      Yemen 2014-01-01  Mean Years of Schooling  male   4.222000
# 40726      Yemen 2015-01-01  Mean Years of Schooling  male   4.222000
# 40727      Yemen 2016-01-01  Mean Years of Schooling  male   4.222000
# 40728      Yemen 2017-01-01  Mean Years of Schooling  male   4.222000
# 40729      Yemen 2018-01-01  Mean Years of Schooling  male   4.428000
# 40730      Yemen 2019-01-01  Mean Years of Schooling  male   5.146000
# 40731      Yemen 2020-01-01  Mean Years of Schooling  male   5.146000
# 40732      Yemen 2021-01-01  Mean Years of Schooling  male   5.146000
# 40733     Zambia 2011-01-01  Mean Years of Schooling  male   6.725071
# 40734     Zambia 2012-01-01  Mean Years of Schooling  male   6.750837
# 40735     Zambia 2013-01-01  Mean Years of Schooling  male   6.776604
# 40736     Zambia 2014-01-01  Mean Years of Schooling  male   6.802370
# 40737     Zambia 2015-01-01  Mean Years of Schooling  male   6.828137
# 40738     Zambia 2016-01-01  Mean Years of Schooling  male   6.927522
# 40739     Zambia 2017-01-01  Mean Years of Schooling  male   7.026907
# 40740     Zambia 2018-01-01  Mean Years of Schooling  male   7.126293
# 40741     Zambia 2019-01-01  Mean Years of Schooling  male   7.225678
# 40742     Zambia 2020-01-01  Mean Years of Schooling  male   7.225678
# 40743     Zambia 2021-01-01  Mean Years of Schooling  male   7.225678
# 40744   Zimbabwe 2011-01-01  Mean Years of Schooling  male   8.222792
# 40745   Zimbabwe 2012-01-01  Mean Years of Schooling  male   8.270920
# 40746   Zimbabwe 2013-01-01  Mean Years of Schooling  male   8.567160
# 40747   Zimbabwe 2014-01-01  Mean Years of Schooling  male   8.863400
# 40748   Zimbabwe 2015-01-01  Mean Years of Schooling  male   8.881024
# 40749   Zimbabwe 2016-01-01  Mean Years of Schooling  male   8.898647
# 40750   Zimbabwe 2017-01-01  Mean Years of Schooling  male   8.916270
# 40751   Zimbabwe 2018-01-01  Mean Years of Schooling  male   9.052420
# 40752   Zimbabwe 2019-01-01  Mean Years of Schooling  male   9.190648
# 40753   Zimbabwe 2020-01-01  Mean Years of Schooling  male   9.190648
# 40754   Zimbabwe 2021-01-01  Mean Years of Schooling  male   9.190648

# %%
final.shape
# Out:
# (40755, 5)

# %%
final['Year'] = pd.to_datetime(final['Year'])
final['Year'] = final['Year'].dt.year

# %%
final['Value'] = final['Value'].round(2)

# %%
final.dtypes
# Out:
# Country       object
# Year           int32
# Indicator     object
# Sex           object
# Value        float64
# dtype: object

# %%
final['Year'] = pd.to_datetime(final['Year'], format='%Y')

# %%
final['Year'].dt.year
# Out:
# 0        2011
# 1        2012
# 2        2013
# 3        2014
# 4        2015
#          ...
# 40750    2017
# 40751    2018
# 40752    2019
# 40753    2020
# 40754    2021
# Name: Year, Length: 40755, dtype: int32

# %%
final['Year'] = pd.to_datetime(final['Year'].dt.year, format='%Y')

# %%
final.dtypes
# Out:
# Country              object
# Year         datetime64[ns]
# Indicator            object
# Sex                  object
# Value               float64
# dtype: object

# %%
#ANALYSISN REMAINING NaNs
final[final.isna().any(axis=1)].head(10)
# Out:
#      Country       Year                    Indicator      Sex  Value
# 3377  Monaco 2011-01-01  Expected Years of Schooling  General    NaN
# 3378  Monaco 2012-01-01  Expected Years of Schooling  General    NaN
# 3379  Monaco 2013-01-01  Expected Years of Schooling  General    NaN
# 3380  Monaco 2014-01-01  Expected Years of Schooling  General    NaN
# 3381  Monaco 2015-01-01  Expected Years of Schooling  General    NaN
# 3382  Monaco 2016-01-01  Expected Years of Schooling  General    NaN
# 3383  Monaco 2017-01-01  Expected Years of Schooling  General    NaN
# 3384  Monaco 2018-01-01  Expected Years of Schooling  General    NaN
# 3385  Monaco 2019-01-01  Expected Years of Schooling  General    NaN
# 3386  Monaco 2020-01-01  Expected Years of Schooling  General    NaN

# %%
final['Indicator'] = final['Indicator'].str.split(',').str[0].str.strip()

# %%
final[final['Value'].isna()].sample(10, random_state=42)
# Out:
#                    Country       Year                         Indicator  \
# 37914                Palau 2019-01-01           Mean Years of Schooling
# 29885               Tuvalu 2020-01-01   Labour force participation rate
# 9082              Djibouti 2018-01-01           Gender Inequality Index
# 20542               Monaco 2016-01-01            Inequality in eduation
# 14558           Seychelles 2016-01-01  Gross National Income Per Capita
# 8640   Antigua and Barbuda 2016-01-01           Gender Inequality Index
# 22996                Qatar 2017-01-01              Inequality in income
# 39118             Dominica 2013-01-01           Mean Years of Schooling
# 16753      Solomon Islands 2011-01-01                               HDI
# 18228        Liechtenstein 2012-01-01                               HDI
#
#            Sex  Value
# 37914   female    NaN
# 29885     male    NaN
# 9082   General    NaN
# 20542  General    NaN
# 14558     male    NaN
# 8640   General    NaN
# 22996  General    NaN
# 39118     male    NaN
# 16753   female    NaN
# 18228     male    NaN

# %%
final['Sex'].isna().sum()
# Out:
# np.int64(0)

# %%
final[final['Value'].isna()] \
    .groupby('Sex').size().sort_values(ascending=False)
# Out:
# Sex
# General    858
# female     836
# male       836
# dtype: int64

# %%
final.to_csv('../data/clean/clean_data.csv', index=False, na_rep="\\N", date_format='%Y-%m-%d')

# %%
# CREATING TABLES FOR MYSQL

# Country table
country_table = (
    final[['Country']]
    .drop_duplicates()
    .sort_values('Country')
    .reset_index(drop=True)
)
country_table['country_id'] = country_table.index + 1

# Indicator table
indicator_table = (
    final[['Indicator']]
    .drop_duplicates()
    .sort_values('Indicator')
    .reset_index(drop=True)
)
indicator_table['indicator_id'] = indicator_table.index + 1

# Sex table
sex_table = (
    final[['Sex']]
    .drop_duplicates()
    .sort_values('Sex')
    .reset_index(drop=True)
)
sex_table['sex_id'] = sex_table.index + 1


# Year table 
final['Year'] = pd.to_datetime(final['Year'], format='%Y')

year_table = (
    final[['Year']]
    .drop_duplicates()
    .sort_values('Year')
    .rename(columns={'Year': 'year_id'})
    .reset_index(drop=True)
)

year_table['year_label'] = year_table['year_id'].dt.year

# %%
# MERGING 

df_fact = final.merge(country_table, on='Country', how='left')
df_fact = df_fact.merge(indicator_table, on='Indicator', how='left')
df_fact = df_fact.merge(sex_table, on='Sex', how='left')


df_fact = df_fact.merge(year_table, left_on='Year', right_on='year_id', how='left')
df_fact.drop(columns=['Year'], inplace=True)  # Optional cleanup

# %%
fact_table = df_fact[['country_id', 'year_id', 'indicator_id', 'sex_id', 'Value']]

# %%
fact_table.isna().sum()
# Out:
# country_id         0
# year_id            0
# indicator_id       0
# sex_id             0
# Value           2530
# dtype: int64

# %%
fact_table[fact_table.isna().any(axis=1)].head(10)
# Out:
#       country_id    year_id  indicator_id  sex_id  Value
# 3377         113 2011-01-01             2       1    NaN
# 3378         113 2012-01-01             2       1    NaN
# 3379         113 2013-01-01             2       1    NaN
# 3380         113 2014-01-01             2       1    NaN
# 3381         113 2015-01-01             2       1    NaN
# 3382         113 2016-01-01             2       1    NaN
# 3383         113 2017-01-01             2       1    NaN
# 3384         113 2018-01-01             2       1    NaN
# 3385         113 2019-01-01             2       1    NaN
# 3386         113 2020-01-01             2       1    NaN

# %%
fact_with_names = fact_table \
    .merge(country_table, on='country_id') \
    .merge(indicator_table, on='indicator_id') \
    .merge(sex_table, on='sex_id') \
    .merge(year_table, on='year_id')

fact_with_names[fact_with_names['Value'].isna()].head()
# Out:
#       country_id    year_id  indicator_id  sex_id  Value Country  \
# 3377         113 2011-01-01             2       1    NaN  Monaco
# 3378         113 2012-01-01             2       1    NaN  Monaco
# 3379         113 2013-01-01             2       1    NaN  Monaco
# 3380         113 2014-01-01             2       1    NaN  Monaco
# 3381         113 2015-01-01             2       1    NaN  Monaco
#
#                         Indicator      Sex  year_label
# 3377  Expected Years of Schooling  General        2011
# 3378  Expected Years of Schooling  General        2012
# 3379  Expected Years of Schooling  General        2013
# 3380  Expected Years of Schooling  General        2014
# 3381  Expected Years of Schooling  General        2015

# %%
fact_with_names[fact_with_names['Value'].isna()] \
    .groupby('Indicator') \
    .size() \
    .sort_values(ascending=False)
# Out:
# Indicator
# HDI                                         506
# Mean Years of Schooling                     352
# Gross National Income Per Capita            352
# Labour force participation rate             330
# Inequality in income                        286
# Gender Inequality Index                     275
# Expected Years of Schooling                 154
# Inequality in eduation                      154
# Maternal Mortality Ratio (deaths per 100    121
# dtype: int64

# %%
fact_table.loc[:, 'is_missing'] = fact_table['Value'].isna().astype(int)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12196\4293666913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fact_table.loc[:, 'is_missing'] = fact_table['Value'].isna().astype(int)

# %%
# Check for duplicates
duplicates = fact_table.duplicated(subset=['country_id', 'year_id', 'indicator_id', 'sex_id'], keep=False)
fact_table[duplicates].sort_values(['country_id', 'year_id', 'indicator_id', 'sex_id'])
# Out:
# Empty DataFrame
# Columns: [country_id, year_id, indicator_id, sex_id, Value, is_missing]
# Index: []

# %%
# EXPORTING ENTITY TABLES

country_table.drop_duplicates(subset=['Country', 'country_id']) \
    .to_csv("../data/clean/country.csv", index=False)

year_table[['year_id', 'year_label']].drop_duplicates() \
    .to_csv("../data/clean/year.csv", index=False)

indicator_table.drop_duplicates(subset=['Indicator', 'indicator_id']) \
    .to_csv("../data/clean/indicator.csv", index=False)

sex_table.drop_duplicates(subset=['Sex', 'sex_id']) \
    .to_csv("../data/clean/sex.csv", index=False)

#fact_table.to_csv("country_year_indicator.csv", index=False, na_rep="\\N")

# %%
# fact_table.to_csv("../data/clean/country_year_indicator_for_wb.csv", index=False, na_rep="NULL")

# %%
fact_table.shape
# Out:
# (40755, 6)

# %%
INPUT_PATH  = "../data/clean/country_year_indicator_for_wb.csv"  # your full fact table
OUTPUT_DIR  = Path("../data/clean")
CHUNK_SIZE  = 10_000

df = pd.read_csv(INPUT_PATH)

df["year_id"] = pd.to_datetime(df["year_id"], errors="coerce").dt.strftime("%Y-%m-%d")

value_col = "Value" if "Value" in df.columns else "value"
df[value_col] = pd.to_numeric(df[value_col], errors="coerce").fillna(0)


OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
df.to_csv(OUTPUT_DIR / "country_year_indicator_for_wb_zeros.csv", index=False)


chunk_paths = []
row_counts = []
for i in range(0, len(df), CHUNK_SIZE):
    part = df.iloc[i:i+CHUNK_SIZE]
    path = OUTPUT_DIR / f"cyi_part_{i//CHUNK_SIZE+1}.csv"
    part.to_csv(path, index=False)
    chunk_paths.append(path)
    row_counts.append(len(part))


total_rows_chunks = sum(row_counts)
print(f"Original total rows: {len(df)}")
print(f"Total rows across chunks: {total_rows_chunks}")
print(f"Number of chunks: {len(chunk_paths)}")
print(f"Chunk sizes: {row_counts}")

if total_rows_chunks == len(df):
    print("All rows accounted for.")
else:
    print("Row count mismatch! Check chunking logic.")
# Out:
# Original total rows: 40755
# Total rows across chunks: 40755
# Number of chunks: 5
# Chunk sizes: [10000, 10000, 10000, 10000, 755]
# All rows accounted for.

# %%
fact_table.head()
# Out:
#    country_id    year_id  indicator_id  sex_id   Value  is_missing
# 0           1 2011-01-01             1       2  116.45           0
# 1           1 2012-01-01             1       2  111.29           0
# 2           1 2013-01-01             1       2  106.54           0
# 3           1 2014-01-01             1       2  101.45           0
# 4           1 2015-01-01             1       2   97.42           0

# %%
final[final.isna().any(axis=1)].head(10)
# Out:
#      Country       Year                    Indicator      Sex  Value
# 3377  Monaco 2011-01-01  Expected Years of Schooling  General    NaN
# 3378  Monaco 2012-01-01  Expected Years of Schooling  General    NaN
# 3379  Monaco 2013-01-01  Expected Years of Schooling  General    NaN
# 3380  Monaco 2014-01-01  Expected Years of Schooling  General    NaN
# 3381  Monaco 2015-01-01  Expected Years of Schooling  General    NaN
# 3382  Monaco 2016-01-01  Expected Years of Schooling  General    NaN
# 3383  Monaco 2017-01-01  Expected Years of Schooling  General    NaN
# 3384  Monaco 2018-01-01  Expected Years of Schooling  General    NaN
# 3385  Monaco 2019-01-01  Expected Years of Schooling  General    NaN
# 3386  Monaco 2020-01-01  Expected Years of Schooling  General    NaN

# %%
fact_table.dtypes
# Out:
# country_id               int64
# year_id         datetime64[ns]
# indicator_id             int64
# sex_id                   int64
# Value                  float64
# is_missing               int64
# dtype: object
